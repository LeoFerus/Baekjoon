# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoFerus/Baekjoon/blob/main/9%EC%9B%94_5%EC%9D%BC_%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c = 3
c
# Out:
# 3

# %%
var1 = [1,2,3]
var = ['a','a','b','c']

# %% [markdown]
# var1 에 저장을 하면 1,2,3이 리스트에 들어가있는 것을 확인할 수 있다.
#
# 리스트와 리스트는 서로 덧셈을 할 수 없다. 더하기 연산자를 사용하게 되면 두 리스트의 원소가 모인 하나의 리스트가 된다.

# %%
str1 = 'a'

# %% [markdown]
# 문자가 들어 있는 변수끼리 더하면 순서대로 결합해서 보여줍니다.

# %%
import seaborn as sns

df = sns.load_dataset('titanic')

# %%
seaborn.countplot(data = df, x ='sex')

# %%
seaborn.countplot(x=var)

# %%
sns.countplot(data = df, x='sex')

# %%
sns.countplot(data = df , x = 'class')
sns.countplot(data = df , x = 'class',hue = 'alive')
sns.countplot(data = df , y = 'class' ,hue = 'alive')

# %%
sns.countplot(data = df , x = 'class')

# %%
sns.countplot(data = df , x = 'class',hue = 'alive')

# %%
sns.countplot(data = df , y = 'class' ,hue = 'alive')

# %%
sns.countplot?

# %%
import sklearn.metrics
sklearn.metrics.accuracy_score()

# %%
from sklearn import metrics
metrics.accuracy_score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-a04d6564e814> in <module>
#       1 from sklearn import metrics
# ----> 2 metrics.accuracy_score()
#
# TypeError: accuracy_score() missing 2 required positional arguments: 'y_true' and 'y_pred'

# %%
from sklearn.metrics import accuracy_score

accuracy_score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-682df7ea9574> in <module>
#       1 from sklearn.metrics import accuracy_score
#       2
# ----> 3 accuracy_score()
#
# TypeError: accuracy_score() missing 2 required positional arguments: 'y_true' and 'y_pred'

# %%
import sklearn.metrics as met 
met.accuracy_score()

from sklearn import metrics as metrics
met.accuracy_score()

from sklearn.metrics import accuracy_score as accuracy_score
accuracy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-674d7b1cd33a> in <module>
#       1 import sklearn.metrics as met
# ----> 2 met.accuracy_score()
#       3
#       4 from sklearn import metrics as metrics
#       5 met.accuracy_score()
#
# TypeError: accuracy_score() missing 2 required positional arguments: 'y_true' and 'y_pred'

# %%
# %pip install pydataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pydataset
pydataset.data()
# Out:
# initiated datasets repo at: /root/.pydataset/
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
df = pydataset.data('mtcars')
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sil = sns.load_dataset('iris')
sil
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
sns.countplot(data = sil , x = 'species')
